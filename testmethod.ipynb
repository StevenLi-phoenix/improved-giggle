# %%
"""result-op c-container xpath-log new-pmd"""
# Out:
# 'result-op c-container xpath-log new-pmd'

# %%
import requests, time, random
from bs4 import BeautifulSoup as BS

# %%
class Worm:
    def __init__(self):
        self.user_agent = ["Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36", "Mozilla/5.0 (Windows; U; Windows NT 6.1; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50", "Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0)", "Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/20100101 Firefox/4.0.1", "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; 360SE)", "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36", "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.0 Safari/537.36", "Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2049.0 Safari/537.36", "Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:22.0) Gecko/20130328 Firefox/22.0", "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1464.0 Safari/537.36", "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1623.0 Safari/537.36", "Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36", "Mozilla/5.0 (X11; NetBSD) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.116 Safari/537.36", "Mozilla/5.0 (Windows NT 5.0; rv:21.0) Gecko/20100101 Firefox/21.0", "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1664.3 Safari/537.36", "Opera/9.80 (Windows NT 5.1; U; cs) Presto/2.7.62 Version/11.01", "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1944.0 Safari/537.36", "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:21.0) Gecko/20130331 Firefox/21.0", "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36", "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36", "Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.93 Safari/537.36", "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36", "Mozilla/5.0 (X11; OpenBSD i386) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36", "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1847.137 Safari/4E423F", "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36"]
        self.decodetype = "utf-8"
        self.ogs = []

    def BS(self, content):
        """
        convert content to html parser
        :param content: String
        :return: String
        """
        return BS(content, "html.parser")

    def header(self):
        """
        Select an header with random UA
        :return: String
        """
        headers = {
            "user-agent": random.choice(self.user_agent),
        }
        return headers

    def handle_request(self, url, max_retry_time=10):
        try: 
            respon = requests.get(url=url, headers=self.header(), timeout=1)
            if respon.content is None: raise Exception(f"respon content is None max_retry_time:{max_retry_time}")
        except Exception as e:
            if max_retry_time >= 0:
                print("SLEEP")
                time.sleep(1)
                respon = self.handle_request(url, max_retry_time - 1)
            else:
                raise ConnectionRefusedError(f"Retried too many times!!! Server refuse connection.\n{e}")
        return respon
    def open_url(self, url, max_retry_time=10):
        print(f"Start {url}")
        return self.handle_request(url, max_retry_time).content.decode()

# %%
w = Worm()

# %%
content = w.BS(w.open_url("https://www.baidu.com/s?wd=无限先知"))
# Out:
# Start https://www.baidu.com/s?wd=无限先知

# %%
result = content.find_all("div", attrs={"class":"result-op c-container xpath-log new-pmd"})

# %%
len(result)
# Out:
# 8

# %%
for re in result:
    print(re["mu"])
# Out:
# https://www.xbiquge.la/19/15484/
# https://www.ddbiquge.cc/book/47784.html
# https://www.7722.org/html/64285/
# null
# https://baike.baidu.com/item/%E6%97%A0%E9%99%90%E5%85%88%E7%9F%A5/22296950
# https://www.yqxs.cc/html/110/110783/index.html
# http://tieba.baidu.com/f?kw=%CE%DE%CF%DE%CF%C8%D6%AA&fr=ala0&loc=rec&tids=7574989514,7616151566,7418536528
# https://www.xyangguiweihuo.com/6/6700/

# %%
import json, random, time
from tabnanny import check
from re import S, search
from tokenize import String
import requests
from bs4 import BeautifulSoup as BS
from sklearn.feature_selection import SelectKBest



class Worm:
    def __init__(self):
        self.user_agent = ["Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36", "Mozilla/5.0 (Windows; U; Windows NT 6.1; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50", "Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0)", "Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/20100101 Firefox/4.0.1", "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; 360SE)", "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36", "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.0 Safari/537.36", "Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2049.0 Safari/537.36", "Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:22.0) Gecko/20130328 Firefox/22.0", "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1464.0 Safari/537.36", "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1623.0 Safari/537.36", "Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36", "Mozilla/5.0 (X11; NetBSD) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.116 Safari/537.36", "Mozilla/5.0 (Windows NT 5.0; rv:21.0) Gecko/20100101 Firefox/21.0", "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1664.3 Safari/537.36", "Opera/9.80 (Windows NT 5.1; U; cs) Presto/2.7.62 Version/11.01", "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1944.0 Safari/537.36", "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:21.0) Gecko/20130331 Firefox/21.0", "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36", "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36", "Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.93 Safari/537.36", "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36", "Mozilla/5.0 (X11; OpenBSD i386) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36", "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1847.137 Safari/4E423F", "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36"]
        self.decodetype = "utf-8"
        self.ogs = []

    def BS(self, content):
        """
        convert content to html parser
        :param content: String
        :return: String
        """
        return BS(content, "html.parser")

    def header(self):
        """
        Select an header with random UA
        :return: String
        """
        headers = {
            "user-agent": random.choice(self.user_agent),
        }
        return headers

    def handle_request(self, url, max_retry_time=10):
        try: 
            respon = requests.get(url=url, headers=self.header(), timeout=1)
            if respon.content is None: raise Exception(f"respon content is None max_retry_time:{max_retry_time}")
        except Exception as e:
            if max_retry_time >= 0:
                time.sleep(1)
                respon = self.handle_request(url, max_retry_time - 1)
            else:
                raise ConnectionRefusedError(f"Retried too many times!!! Server refuse connection.\n{e}")
        return respon
    def open_url(self, url, max_retry_time=10):
        return self.handle_request(url, max_retry_time).content.decode()

# ________________________________________________________________________________________________________________________________
    def autoSearchAltsite(self, novelName):
        altsite = self.searchMethod1(novelName)
        if altsite!="-1": return altsite
        altsite = self.searchMethod2(novelName)
        if altsite!="-1": return altsite
        print("Alt search failed")
        return "autoSearchFailed"
        
    def searchMethod1(self, novelName):
        print("Altsit 1")
        altsite = "-1"
        base = "https://www.biqugee.com"
        request_url = f"https://www.biqugee.com/search.php?q={novelName}"
        respon = self.open_url(request_url)
        try:
            altsite = base + self.BS(respon).find("a",{"cpos":"title","class":"result-game-item-title-link"})["href"]
            return altsite
        except TypeError:
            return altsite

    def searchMethod2(self, novelName):
        print("Altsit 2")
        altsite = "-1"
        base = "https://www.baidu.com"
        request_url = f"https://www.baidu.com/s?wd={novelName}"
        respon = self.open_url(request_url)
        return respon
        try:
            result = self.BS(respon).find_all("div", attrs={"class":"result-op c-container xpath-log new-pmd"})
            
            for re in result:
                if re["mu"] is not "null":
                    altsite = re["mu"]
                    break
            return altsite
        except Exception as e:
            return altsite
# ________________________________________________________________________________________________________________________________
    
    def infoPage(self, url, altsite="404.html", append=True, autoSearchAltsite=True):
        print(f"Start infoPage {url}")
        """
        get info from qidian.com substract from standard header
        :param url: book url(qidian.com)
        :return: return bookinfo if append is False else add info to self.ogs list
        """
        content = self.BS(self.open_url(url))
        og = {
            "url":url,
            "type":content.find("meta", {"property":"og:type"})["content"],
            "title": content.find("meta", {"property": "og:title"})["content"],
            "description": content.find("meta", {"property": "og:description"})["content"],
            "image": content.find("meta", {"property": "og:image"})["content"],
            "novel:category":content.find("meta", {"property": "og:novel:category"})["content"],
            "novel:author": content.find("meta", {"property": "og:novel:author"})["content"],
            "novel:book_name": content.find("meta", {"property": "og:novel:book_name"})["content"],
            "novel:read_url": content.find("meta", {"property": "og:novel:read_url"})["content"],
            "novel:status": content.find("meta", {"property": "og:novel:status"})["content"],
            "novel:author_link": content.find("meta", {"property": "og:novel:author_link"})["content"],
            "novel:update_time": content.find("meta", {"property": "og:novel:update_time"})["content"],
            "novel:latest_chapter_name": content.find("meta", {"property": "og:novel:latest_chapter_name"})["content"],
            "novel:latest_chapter_url": content.find("meta", {"property": "og:novel:latest_chapter_url"})["content"],
        }
        if og["image"].endswith("300"):og["image"] = og["image"][:-3]+"180"
        if altsite== "404.html" and autoSearchAltsite:
            altsite = self.autoSearchAltsite(og["title"])
        og["altsite"]=altsite
        if append:
            self.ogs.append(og)
        else:
            return og

    def append_info_data(self, bookinfo):
        """
        append book info to json file to storage
        :param bookinfo: og data
        :return: None
        """
        with open("info.json", "r") as f:
            data = json.loads(f.read())
        if bookinfo not in data:
            data.append(bookinfo)
            with open("info.json", "w") as f:
                f.write(json.dumps(data))

    def replace_info_data(self, bookinfos):
        """
        replace content in info.json
        :param bookinfo: og datas
        :return: None
        """
        with open("info.json", "w") as f:
            f.write(json.dumps(bookinfos))
            
    def nameSearch(self, name, autoPost = True):
        print(f"Start Name search {name}")
        base = "https:"
        request_url = f"https://www.qidian.com/soushu/{name}.html"
        respon = self.BS(self.open_url(request_url))
        try:
            infoPage = base + respon.find("li",{"class":"res-book-item"}).find("h2",{"class":"book-info-title"}).a["href"]
        except (TypeError, AttributeError) as e:
            with open("log/search.html", "w") as f:
                f.write(str(respon))
            print(e)
            print("Search None save html file to log/search.html")
            return -1
        if autoPost:
            self.infoPage(infoPage, autoSearchAltsite=True)
        else:
            return infoPage

    def output(self, append=False):
        assert len(self.ogs) > 0
        if append:
            for og in self.ogs:
                self.append_info_data(og)
        else:
            self.replace_info_data(self.ogs)
    

class webManager:
    def setSelfInfo(self):
         with open("info.json", "r") as f:
            self.info = json.loads(f.read())
    def update(self, mod="from local", ogs=None):
        if mod == "from local":
            self.setSelfInfo()
        elif mod == "from local append":
            self.setSelfInfo()
            for og in ogs:
                if og not in self.info:
                    self.info.append(og)
        elif mod == "from worm":
            self.info = ogs
        txt = []
        for og in self.info:
            text_replacement = f"""<tr>
            <td style="width: 180px;height: 240px;""><div class="zoom"><a href="{og["url"]}">
            <img
                    src="https:{og["image"]}" alt="bookCover"></a></div>
            </td>

            <td style="width:100%;">
                <a href="{og["url"]}">{og["novel:book_name"]}</a>
                <div id="book_intro" style="text-align:left;width:100%;height:max-content;">
                    <p>
                        {og["description"]}
                    </p>
                </div>
                <div id="links">
                    链接：<br>
                    <a href="{og["novel:read_url"]}"><button>{og["url"].split("/")[2]}</button></a>
                    <a href="{og["altsite"]}"><button>{og["altsite"]}</button></a>
                    </div>
                </td>
                </tr>"""
            txt.append(text_replacement)
        with open("template/index.html", "r") as f: temp = str(f.read())
        with open("index.html", "w") as f:
            f.write(temp.replace("replace", "\n".join(txt)))
    def update_from_worm(self, ogs):
        self.update(mod="from worm", ogs=ogs)
    def update_from_local_append(self, ogs):
        self.update(mod="from local append", ogs=ogs)   

class subpages:
    def __init__(self):
        self.ogs = list(json.load(open("info.json", "w")))
        print(self.ogs)

if __name__ == '__main__':
    worm = Worm()
    if False:
        worm.infoPage("https://book.qidian.com/info/1009480992/", altsite="https://www.biqugee.com/book/18461/") #超神机械师
        worm.infoPage("https://book.qidian.com/info/1021617576/", altsite="https://www.ddyueshu.com/27171_27171574/") #夜的命名术
        worm.infoPage("https://book.qidian.com/info/1029006481/", altsite="https://www.biqugee.com/book/49472/") #不科学御兽
        worm.infoPage("https://book.qidian.com/info/1025901449/", altsite="https://www.biqugee.com/book/42560/") #我的治愈系游戏
        worm.infoPage("https://book.qidian.com/info/1023867124/", altsite="https://www.biqugee.com/book/39312/") #我家老婆来自一千年前
        worm.infoPage("https://book.qidian.com/info/1016150754/", altsite="https://www.biqugee.com/book/30784/") #亏成首富从游戏开始
        worm.infoPage("https://book.qidian.com/info/1015525869/", altsite="https://www.biqugee.com/book/30809/") #变成血族是什么体验
        worm.infoPage("https://book.qidian.com/info/1013293257/", altsite="https://www.biqugee.com/book/25454/") #舌尖上的霍格沃茨
        worm.infoPage("https://book.qidian.com/info/1012284323/", altsite="https://www.biqugee.com/book/22980/") #我有一座冒险屋
        worm.infoPage("https://book.qidian.com/info/1003306811/", altsite="https://www.biqugee.com/book/3600/") #放开那个女巫
        worm.infoPage("https://book.qidian.com/info/2718601/", altsite="https://www.biqugee.com/book/1876/") #进化的四十六亿重奏
        worm.infoPage("https://book.qidian.com/info/3681932/", altsite="https://www.biqugee.com/book/15409/") #名侦探世界里的巫师
        worm.infoPage("https://book.qidian.com/info/1025263752/", altsite="https://www.biqugee.com/book/41199/") #二进制亡者列车
        worm.infoPage("https://book.qidian.com/info/1022282526/", altsite="https://www.biqugee.com/book/37421/") #全职艺术家
    # worm.nameSearch("无限先知")

# %%
worm.ogs
# Out:
# [{'url': 'https://book.qidian.com/info/1010144088/',
#   'type': 'novel',
#   'title': '无限先知',
#   'description': '\u3000\u3000新书已发《邪神竟是我自己！》记得要打感叹号。\n徐越穿越到了一个与地球有些类似的平行世界，而后被拉入了这个世界的轮回空间，有趣的是，只有他才知道轮回空间诸多世界当中的剧情。\n“你知道吗？忍村大战的最终BOSS叫大蛇丸……”\n火影、巨人、死神、食戟、漫威、高达、艾泽拉斯、一拳、柯南、overlord、fate、龙珠、哈利波特、仙剑、棋魂、DC、盘龙、杀戮都市、遮天、港综圣杯、一世之尊、诡秘之主……\n靠着对剧情先知先觉的理解，一步先步步先！\nPS1：已完本《星际传承》《唯一进化者》《机甲战神》《破法之眼》节操满满放心食用。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1010144088/180',
#   'novel:category': '无限',
#   'novel:author': '吴杰超',
#   'novel:book_name': '无限先知',
#   'novel:read_url': 'https://book.qidian.com/info/1010144088/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/4362734/',
#   'novel:update_time': '2022-03-04',
#   'novel:latest_chapter_name': '完本感言',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1010144088/702053525/',
#   'altsite': 'autoSearchFailed'}]

# %%
a = worm.searchMethod2("无限先知")
# Out:
# Altsit 2

# %%
worm.BS(a)
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-CN">
# <head>
# <meta charset="utf-8"/>
# <title>百度安全验证</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="width=device-width, user-scalable=no, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="telephone=no, email=no" name="format-detection"/>
# <link href="https://www.baidu.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.baidu.com/img/baidu.svg" mask="" rel="icon" sizes="any"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="upgrade-insecure-requests" http-equiv="Content-Security-Policy"/>
# <link href="https://ppui-static-wap.cdn.bcebos.com/static/touch/css/api/mkdjump_0635445.css" rel="stylesheet">
# </link></head>
# <body>
# <div class="timeout hide">
# <div class="timeout-img"></div>
# <div class="timeout-title">网络不给力，请稍后重试</div>
# <button class="timeout-button" type="button">返回首页</button>
# </div>
# <div class="timeout-feedback hide">
# <div class="timeout-feedback-icon"></div>
# <p class="timeout-feedback-title">问题反馈</p>
# </div>
# <script src="https://wappass.baidu.com/static/machine/js/api/mkd.js"></script>
# <script src="https://ppui-static-wap.cdn.bcebos.com/static/touch/js/mkdjump_eac1ee5.js"></script>
# </body>
# </html>

# %%
c = worm.open_url("https://cn.bing.com/search?q=%E6%97%A0%E9%99%90%E5%85%88%E7%9F%A5")

# %%
w = worm
c = w.BS(c)

# %%
r = c.find_all("li", attrs={"class":"b_algo"})

# %%
len(r)
# Out:
# 10

# %%
for re in r:
    print(re.div.a["href"])
# Out:
# https://www.81zw.com/book/29992/
# https://baike.baidu.com/item/%E6%97%A0%E9%99%90%E5%85%88%E7%9F%A5/22296950
# https://www.bbiquge.net/book_93372/
# http://vip.book.sina.com.cn/weibobook/book/5483008.html?nwm=weiboamp%3B_nc_ht%3Dscontent-iad3-1.xx
# http://www.355book.com/book/335/
# https://www.xxbiqudu.com/72_72983/177085858.html
# https://www.imiaobige.com/novel/50010.html
# https://www.umiwx.com/read/64062.html
# https://www.shuhaige.net/859_3/
# https://jingyan.baidu.com/article/93f9803fcc9adaa1e46f558c.html

# %%
import json as j

# %%
s = list(j.load(open("info.json", "r")))

# %%
d = []
for s_i in s:
    if s_i["title"] in d:
       s.remove(s_i)
    else:
       s.append(s_i["title"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f694e9244fe2> in <module>
#       2 for s_i in s:
#       3     if s_i["title"] in d.keys():
# ----> 4        s.pop(s_i)
#       5     else:
#       6         d[s_i["title"]] = 1
#
# TypeError: 'dict' object cannot be interpreted as an integer

# %%
s
# Out:
# [{'url': 'https://book.qidian.com/info/1022305499/',
#   'type': 'novel',
#   'title': '万界点名册',
#   'description': '\u3000\u3000「三年后的我会是什么形状？」大学宿舍中，失眠的许奇寂在思考。<br>\u3000\u3000次日，清晨。<br>\u3000\u3000他得到了想要的答案。<br>\u3000\u3000.<br>\u3000\u3000.<br>\u3000\u3000书友群<br>\u3000\u30001号群1121579815（普群）<br>\u3000\u30002号群1139981904（普群）',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1022305499/180',
#   'novel:category': '都市异能',
#   'novel:author': '圣骑士的传说',
#   'novel:book_name': '万界点名册',
#   'novel:read_url': 'https://book.qidian.com/info/1022305499/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/4362241/',
#   'novel:update_time': '2021-08-24',
#   'novel:latest_chapter_name': '王者荣耀·曜的短篇《闪耀》即将上线',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1022305499/670453817/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1009480992/',
#   'type': 'novel',
#   'title': '超神机械师',
#   'description': '\u3000\u3000韩萧，《星海》骨灰级代练，被来自东（zuo）方(zhe)的神秘力量扔进穿越大军，携带玩家面板变成NPC，回到《星海》公测之前，毅然选择难度最高的机械系。<br>\u3000\u3000战舰列队纵横星海，星辰机甲夭矫如龙，幽能炮毁天灭地，还有无边无际的机械大军，静静待在随身仓库里<br>\u3000\u3000一人，即是军团！<br>\u3000\u3000如果不是玩家出现，本书就是正经严肃的穿越异界题材……<br>\u3000\u3000作为NPC，正常NPC对玩家功能一应俱全……发布任务？好感度调节？传授技能？<br>\u3000\u3000哎等等，这群玩家我怎么都认识<br>\u3000\u3000得，现实世界也回到了十年前。<br>\u3000\u3000二群：157302881<br>\u3000\u3000三群：884339155<br>\u3000\u3000V群：547599250（需1w粉丝值由管理审核）',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1009480992/180',
#   'novel:category': '游戏异界',
#   'novel:author': '齐佩甲',
#   'novel:book_name': '超神机械师',
#   'novel:read_url': 'https://book.qidian.com/info/1009480992/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/4185352/',
#   'novel:update_time': '2021-10-24',
#   'novel:latest_chapter_name': '新书《星界使徒》发布！',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1009480992/680523480/',
#   'altsite': 'https://www.biqugee.com/book/18461/'},
#  {'url': 'https://book.qidian.com/info/1021617576/',
#   'type': 'novel',
#   'title': '夜的命名术',
#   'description': '\u3000\u3000蓝与紫的霓虹中，浓密的钢铁苍穹下，数据洪流的前端，是科技革命之后的世界，也是现实与虚幻的分界。<br>\u3000\u3000钢铁与身体，过去与未来。<br>\u3000\u3000这里，表世界与里世界并存，面前的一切，像是时间之墙近在眼前。<br>\u3000\u3000黑暗逐渐笼罩。<br>\u3000\u3000可你要明白啊我的朋友，我们不能用温柔去应对黑暗，要用火。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1021617576/180',
#   'novel:category': '异术超能',
#   'novel:author': '会说话的肘子',
#   'novel:book_name': '夜的命名术',
#   'novel:read_url': 'https://book.qidian.com/info/1021617576/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/5175790/',
#   'novel:update_time': '10小时前',
#   'novel:latest_chapter_name': '641、远方的朋友',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1021617576/701243587/',
#   'altsite': 'https://www.ddyueshu.com/27171_27171574/'},
#  {'url': 'https://book.qidian.com/info/1029006481/',
#   'type': 'novel',
#   'title': '不科学御兽',
#   'description': '\u3000\u3000这是一个以御兽为主流的异世界。\n动物，植物，元素，死灵，机械……九尾炎狐，生命古树，雷云精灵，骷髅君主，机械舰娘乃至孕育出灵的古董刀剑皆可作为宠兽，而契约、培养，御使它们的人类，则被统称为御兽师！\n神话学者兼考古学家时宇穿越而来，为了探寻空白的历史与失落的神话，他选择踏上了一条极为不科学的御兽之路…',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1029006481/180',
#   'novel:category': '异世大陆',
#   'novel:author': '轻泉流响',
#   'novel:book_name': '不科学御兽',
#   'novel:read_url': 'https://book.qidian.com/info/1029006481/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/400116550/',
#   'novel:update_time': '11小时前',
#   'novel:latest_chapter_name': '第358章：冻结时间的天霜寒气',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1029006481/701019327/',
#   'altsite': 'https://www.biqugee.com/book/49472/'},
#  {'url': 'https://book.qidian.com/info/1025901449/',
#   'type': 'novel',
#   'title': '我的治愈系游戏',
#   'description': '\u3000\u3000警察同志，如果我说这是一款休闲治愈系游戏，你们信吗？',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1025901449/180',
#   'novel:category': '侦探推理',
#   'novel:author': '我会修空调',
#   'novel:book_name': '我的治愈系游戏',
#   'novel:read_url': 'https://book.qidian.com/info/1025901449/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/402573440/',
#   'novel:update_time': '15小时前',
#   'novel:latest_chapter_name': '第637章 不能退出的死亡游戏',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1025901449/701189937/',
#   'altsite': 'https://www.biqugee.com/book/42560/'},
#  {'url': 'https://book.qidian.com/info/1023867124/',
#   'type': 'novel',
#   'title': '我家老婆来自一千年前',
#   'description': '\u3000\u3000“我想回家。”\n“你可能回不去了。”\n“为什么？”\n“因为这里离你家很远。”\n“有多远？”\n“一千二百多年那么远。”\n许青看着眼前来自唐朝的少女，脸上带有一丝同情：“你所熟悉的一切，都已经变成历史。”\n亲朋，好友，敌人，全部沉寂在一千二百年前。\n———\n日常文，单女主\n（已有完本精品，质量保证。）\n新书《黎明之劫》已发。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1023867124/180',
#   'novel:category': '恋爱日常',
#   'novel:author': '花还没开',
#   'novel:book_name': '我家老婆来自一千年前',
#   'novel:read_url': 'https://book.qidian.com/info/1023867124/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/429748736/',
#   'novel:update_time': '2021-07-27',
#   'novel:latest_chapter_name': '新书已发',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1023867124/664339894/',
#   'altsite': 'https://www.biqugee.com/book/39312/'},
#  {'url': 'https://book.qidian.com/info/1016150754/',
#   'type': 'novel',
#   'title': '亏成首富从游戏开始',
#   'description': '\u3000\u3000近日，特约记者对腾达集团总裁裴谦做了专访。\n腾达集团目前估值已达千亿级别，业务涉及游戏、互联网、数码硬件、文化传媒、餐饮等多个领域，深刻地改变了人们生活的方方面面。\n而裴谦，也被视为“绝世好老板”、“不世出的投资奇才”、“天才游戏制作人”，拥有“无为而治的管理才能”和“对行业风向的精确洞察力”。\n面对记者，裴谦大吐苦水。\n“我真不是什么商业奇才啊！”\n“我的成功，完完全全都是运气使然！”\n“我最初的目标，只是想亏光五万块而已……”\n看，商业天才的人生就是这么的谦虚而又低调。\n书友群：\n792351511（新群）\n1064135703（快满了）\n893157567（快满了）',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1016150754/180',
#   'novel:category': '游戏系统',
#   'novel:author': '青衫取醉',
#   'novel:book_name': '亏成首富从游戏开始',
#   'novel:read_url': 'https://book.qidian.com/info/1016150754/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/10454296/',
#   'novel:update_time': '2021-08-10',
#   'novel:latest_chapter_name': '完本感言',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1016150754/665672012/',
#   'altsite': 'https://www.biqugee.com/book/30784/'},
#  {'url': 'https://book.qidian.com/info/1015525869/',
#   'type': 'novel',
#   'title': '变成血族是什么体验',
#   'description': '\u3000\u3000“变成吸血鬼是什么体验？”\n向坤没想到，这个不久前在知乎上被他把答案当成故事来看的问题，现在居然可以用亲身经历来回答了。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1015525869/180',
#   'novel:category': '都市生活',
#   'novel:author': '神行汉堡',
#   'novel:book_name': '变成血族是什么体验',
#   'novel:read_url': 'https://book.qidian.com/info/1015525869/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/402537982/',
#   'novel:update_time': '2021-07-05',
#   'novel:latest_chapter_name': '新书《我的秘书是狐妖》已发布',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1015525869/659783481/',
#   'altsite': 'https://www.biqugee.com/book/30809/'},
#  {'url': 'https://book.qidian.com/info/1013293257/',
#   'type': 'novel',
#   'title': '舌尖上的霍格沃茨',
#   'description': '\u3000\u3000艾琳娜·卡斯兰娜，混血媚娃，危险等级：【极度致命】<br>\u3000\u3000她消弭了千年来学院间的纷争，让霍格沃茨成为圣地。<br>\u3000\u3000她挽救了无数濒危的神奇动物，增进人与自然的了解。<br>\u3000\u3000她促使了魔法与非魔法的融合，找到两者共存平衡点。<br>\u3000\u3000她有着无数耀眼的头衔——霍格沃茨大姐头、古灵阁之主、三代目黑魔王、顶端掠食者、苏格兰圆脸胖鸡之敌、首席特级厨师……<br>\u3000\u3000在她的成长经历中，有无数璀璨的姓名，邓布利多、格林德沃、斯卡曼德……<br>\u3000\u3000——下面我们来采访一下邓布利多。<br>\u3000\u3000“您好，能分享一些卡斯兰娜女士在学校的故事吗？”<br>\u3000\u3000阿不思·心好累好想退休·邓布利多：快……快，我需要速效救心丸！<br>\u3000\u3000【慎入，女主文】',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1013293257/180',
#   'novel:category': '现代魔法',
#   'novel:author': '幽萌之羽',
#   'novel:book_name': '舌尖上的霍格沃茨',
#   'novel:read_url': 'https://book.qidian.com/info/1013293257/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/400090919/',
#   'novel:update_time': '6小时前',
#   'novel:latest_chapter_name': '第1236章 不相同的担忧',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1013293257/701260874/',
#   'altsite': 'https://www.biqugee.com/book/25454/'},
#  {'url': 'https://book.qidian.com/info/1012284323/',
#   'type': 'novel',
#   'title': '我有一座冒险屋',
#   'description': '\u3000\u3000【本作品简体实体书由次元书馆出版】<br>\u3000\u3000陈歌继承了失踪父母留下的冒险屋，无奈生意萧条，直到整理冒险屋时意外发现的手机改变了这一切。<br>\u3000\u3000只要完成手机每日布置的不同难度的任务，冒险屋就能得到修缮甚至扩建！<br>\u3000\u3000于是陈歌开始在各大禁地里探险取材，将其中场景元素纳入到自己的冒险屋中。随着前来参观的游客们各种惊声尖叫，冒险屋一举成名！然而虽然任务带来的好处越来越多，但其中隐患也慢慢显现，甚至父母失踪的线索似乎也藏其中……<br>\u3000\u3000书友一群819098233；二群724779368；三群946284995',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1012284323/180',
#   'novel:category': '侦探推理',
#   'novel:author': '我会修空调',
#   'novel:book_name': '我有一座冒险屋',
#   'novel:read_url': 'https://book.qidian.com/info/1012284323/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/402573440/',
#   'novel:update_time': '2021-01-25',
#   'novel:latest_chapter_name': '新书发布~我的治愈系游戏',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1012284323/632222071/',
#   'altsite': 'https://www.biqugee.com/book/22980/'},
#  {'url': 'https://book.qidian.com/info/1003306811/',
#   'type': 'novel',
#   'title': '放开那个女巫',
#   'description': '\u3000\u3000程岩原以为穿越到了欧洲中世纪，成为了一位光荣的王子。但这世界似乎跟自己想的不太一样？女巫真实存在，而且还真具有魔力？\n\n女巫种田文，将种田进行到底。\n————\n新书《天道方程式》已经发布，请求投喂！',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1003306811/180',
#   'novel:category': '史诗奇幻',
#   'novel:author': '二目',
#   'novel:book_name': '放开那个女巫',
#   'novel:read_url': 'https://book.qidian.com/info/1003306811/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/6052114/',
#   'novel:update_time': '2020-08-20',
#   'novel:latest_chapter_name': '新书《天道方程式》已发，求投喂！',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1003306811/563592635/',
#   'altsite': 'https://www.biqugee.com/book/3600/'},
#  {'url': 'https://book.qidian.com/info/2718601/',
#   'type': 'novel',
#   'title': '进化的四十六亿重奏',
#   'description': '\u3000\u3000从一颗星球的生命诞生之初起跑，将会见证无数文明的兴亡衰落，物种的诞生与灭亡，在数不尽的天灾地变之下，没有什么是永恒不变的，只有不停的改变自身，在逆境之中不停进化，才能成就完美的胜利。<br>\u3000\u3000故事，将从一个小小的细胞开始……<br>\u3000\u3000《重奏》普一群：494981693(千人群)\n\n《重奏》普二群：702899130\n\n重奏VIP群:695413196，入群粉丝值10000',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/2718601/180',
#   'novel:category': '进化变异',
#   'novel:author': '相位行者',
#   'novel:book_name': '进化的四十六亿重奏',
#   'novel:read_url': 'https://book.qidian.com/info/2718601/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/2265405/',
#   'novel:update_time': '2022-02-25',
#   'novel:latest_chapter_name': '第四十一章 末日？',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/2718601/700957012/',
#   'altsite': 'https://www.biqugee.com/book/1876/'},
#  {'url': 'https://book.qidian.com/info/3681932/',
#   'type': 'novel',
#   'title': '名侦探世界里的巫师',
#   'description': '\u3000\u3000一个末法时代的鬼巫师车祸被撞死，灵魂穿越，发现自己来了日本，附体在了一个日本人的身上。<br>\u3000\u3000正想着要在日本闯出一个名堂来，结果顺手拿起一份报纸扫了一眼——<br>\u3000\u3000工藤新一，日本平成年代的福尔摩斯，警察的救世主？<br>\u3000\u3000卧槽，老子怎么穿到二次元的世界里了？<br>\u3000\u3000嗯，总而言之，这是一个巫师在柯南世界里充当路人甲的故事……<br>\u3000\u3000PS：作者菌另外有完本作品《炼鬼修仙》653万字，《邪道鬼尊》365万字，《我的机械章鱼》218万字。闲着无聊的朋友们，可以去看下。<br>\u3000\u3000好吧，还有一本《最后的修仙者》，此书被封中，所以无视掉吧……<br>\u3000\u3000群号：512240405，已满~二群：670934518',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/3681932/180',
#   'novel:category': '衍生同人',
#   'novel:author': '追梦人Love平',
#   'novel:book_name': '名侦探世界里的巫师',
#   'novel:read_url': 'https://book.qidian.com/info/3681932/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/1630719/',
#   'novel:update_time': '2021-01-24',
#   'novel:latest_chapter_name': '第2260章 今天太阳是打西边出来了吗？',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/3681932/632126698/',
#   'altsite': 'https://www.biqugee.com/book/15409/'},
#  {'url': 'https://book.qidian.com/info/1025263752/',
#   'type': 'novel',
#   'title': '二进制亡者列车',
#   'description': '\u3000\u3000图灵误入了一辆满载科技世界亡者的列车。<br>\u3000\u3000进入亡者原本的世界，完成已死之人的遗愿，就能得到他们的高科技知识：<br>\u3000\u3000把血肉变成机械的脱碳原液。<br>\u3000\u3000人造血循环科技吸血鬼。<br>\u3000\u3000入侵大脑的神经拷问技术。<br>\u3000\u3000随时想着夺舍的智能人格。<br>\u3000\u3000空间坍缩炸弹和储物立方。<br>\u3000\u3000高周波武士刀…………<br>\u3000\u3000接着，图灵发现，他还能升级这些知识造物。<br>\u3000\u3000于是，植入式战术目镜变成了高科技眼球：战场透视，自动索敌。<br>\u3000\u3000全息投影器变成了骗术师外骨骼：虚拟分身，容貌覆盖。<br>\u3000\u3000激光炮变成了透射歼星炮。武士刀变成了高频斩舰刀。<br>\u3000\u3000防护罩变成了AT立场……<br>\u3000\u3000机械朋克，意识夺舍。<br>\u3000\u3000血肉苦弱，机械飞升！<br>\u3000\u3000书友群:306055573',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1025263752/180',
#   'novel:category': '无限',
#   'novel:author': 'Krache',
#   'novel:book_name': '二进制亡者列车',
#   'novel:read_url': 'https://book.qidian.com/info/1025263752/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/400480300/',
#   'novel:update_time': '2022-02-26',
#   'novel:latest_chapter_name': '对近况的一个小解释',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1025263752/701064220/',
#   'altsite': 'https://www.biqugee.com/book/41199/'},
#  {'url': 'https://book.qidian.com/info/1022282526/',
#   'type': 'novel',
#   'title': '全职艺术家',
#   'description': '\u3000\u3000“音乐、影视、绘画、书法、雕塑、文学……”\n“你都懂？”\n“略知一二。”\n“都会一点的意思？”\n“嗯，都会亿点的意思。”\n怀揣系统，靠艺术征服世界，成为各界人士顶礼膜拜的无冕之王。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1022282526/180',
#   'novel:category': '娱乐明星',
#   'novel:author': '我最白',
#   'novel:book_name': '全职艺术家',
#   'novel:read_url': 'https://book.qidian.com/info/1022282526/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/4953220/',
#   'novel:update_time': '9小时前',
#   'novel:latest_chapter_name': '第一千二百五十九章 再拿一次十二连冠？',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1022282526/701253176/',
#   'altsite': 'https://www.biqugee.com/book/37421/'},
#  {'url': 'https://book.qidian.com/info/1013887416/',
#   'type': 'novel',
#   'title': '大佬退休之后',
#   'description': '\u3000\u3000【慢穿】<br>\u3000\u3000别人退休，养孙带娃广场舞。<br>\u3000\u3000裴叶退休，氪金养崽纸片人。<br>\u3000\u3000氪金之前：垃圾游戏，骗氪都不上心。<br>\u3000\u3000氪金之后：真香！我不仅能氪我还能肝！<br>\u3000\u3000养纸片人这种事儿呢，它是可以陶冶情操的，丰富退休后的枯燥人生……',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1013887416/180',
#   'novel:category': '东方玄幻',
#   'novel:author': '油爆香菇',
#   'novel:book_name': '大佬退休之后',
#   'novel:read_url': 'https://book.qidian.com/info/1013887416/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/3202780/',
#   'novel:update_time': '2021-08-22',
#   'novel:latest_chapter_name': '1231：番外八（下）',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1013887416/670052709/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1010377389/',
#   'type': 'novel',
#   'title': '全能游戏设计师',
#   'description': '\u3000\u3000游戏设计师陈陌穿越到点歪了科技树的平行世界，用一款又一款神级游戏颠覆游戏圈的故事。<br>\u3000\u3000“就以这个时代的游戏设计理念而言，不把整个游戏行业吊起来打那我真是枉受国产免费游戏洗礼了。”——陈陌。<br>\u3000\u3000书友群：558067640<br>\u3000\u3000VIP群：157856787（进群需全订截图）<br>\u3000\u3000请把推荐票投给新书《超凡玩家》谢谢大家！',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1010377389/180',
#   'novel:category': '游戏系统',
#   'novel:author': '青衫取醉',
#   'novel:book_name': '全能游戏设计师',
#   'novel:read_url': 'https://book.qidian.com/info/1010377389/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/10454296/',
#   'novel:update_time': '2019-06-01',
#   'novel:latest_chapter_name': '新书 主神绘卷',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1010377389/468706459/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1016476783/',
#   'type': 'novel',
#   'title': '科技之全球垄断',
#   'description': '\u3000\u3000从互联网到消费电子，丰富娱乐生活；从云计算到人工智能，颠覆生活方式；从新材料到纳米科技，重塑固有认知；从新能源到军武装备，再扩力量边界；从生物学到临床应用，挽救生命无数……\n一个来自三十年后的超级天才魂穿2003年，用他超越这个时代的视野和科技改变世界，在一个又一个前沿领域发起变革与颠覆的狂潮……\n罗晟(shèng)沉迷科技改变世界，一不小心用科技垄断全球；埋头走自己的路，一不小心让别人无路可走……\n引领变革与颠覆的大浪潮，从一家IT科技公司的诞生开始……\n【书友群：629693065】',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1016476783/180',
#   'novel:category': '超级科技',
#   'novel:author': '昭灵驷玉',
#   'novel:book_name': '科技之全球垄断',
#   'novel:read_url': 'https://book.qidian.com/info/1016476783/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/401750405/',
#   'novel:update_time': '2021-03-11',
#   'novel:latest_chapter_name': '第1028章【新型超导磁浮轨道交通网络系统】',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1016476783/640218241/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1010582019/',
#   'type': 'novel',
#   'title': '科技图书馆',
#   'description': '\u3000\u3000科技图书馆：科学的至高境，就是神学；\n长生不老，飞天遁地，呼风唤雨，移山填海。这些神话传说，科学是可以实现的。想拿这些技术，必须拥有科技图书馆最高权限。\n（新书：天上掉下个科技狂）已上传，求支持。\n\n本故事纯属虚构。\n新的交流群：137230834（蚁窝）',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1010582019/180',
#   'novel:category': '超级科技',
#   'novel:author': '孤胆蚂蚁',
#   'novel:book_name': '科技图书馆',
#   'novel:read_url': 'https://book.qidian.com/info/1010582019/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/6209478/',
#   'novel:update_time': '2021-02-20',
#   'novel:latest_chapter_name': '完本感言',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1010582019/636426826/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1016509432/',
#   'type': 'novel',
#   'title': '世界树的游戏',
#   'description': '\u3000\u3000“虚拟现实游戏”《精灵国度》中人气最高的NPC，世界树的化身，自然之母，生命女神，精灵主宰——\n伊芙·尤克特拉希尔高坐在自己的神座上，微笑地看着台下的玩家们：\n“欢迎来到剑与魔法的世界。”\n这是一个重生成真神的穿越者携第四天灾在异世界共创美好生活的故事（迫真）……\nPS：伪/非DND，幕后玩家流，主角单身\n《世界树的游戏》书友群：674四七四458',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1016509432/180',
#   'novel:category': '原生幻想',
#   'novel:author': '咯嘣',
#   'novel:book_name': '世界树的游戏',
#   'novel:read_url': 'https://book.qidian.com/info/1016509432/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/402002045/',
#   'novel:update_time': '2022-02-16',
#   'novel:latest_chapter_name': '开新书了',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1016509432/699781748/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1016970531/',
#   'type': 'novel',
#   'title': '我真没想当救世主啊',
#   'description': '\u3000\u3000本书又名《千年回溯》。第31届中国科幻银河奖最佳网络文学获奖作品。\n……\n【62章起飞，92章爆炸。这是个凡夫俗子把自己硬顶成文明救世主的故事。】\n1977年，旅行者升空。\n2010年，旅行者二号向地球发送回一些奇怪的信息。\n2021年7月，旅行者二号提前四年彻底失联。\n二十六世纪初，地球文明被封锁圈养。\n3020年10月27日上午十点，人类灭亡。\n在灭亡的前一年，二十一世纪的普通青年陈锋穿越时空，抵达了千年之后，并且他发现自己死后将会回到二十一世纪。\n在未来阅读历史，在历史中改变未来。\n陈锋开始在这看似永恒的循环中，为自己与人类寻找黑暗中的唯一曙光。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1016970531/180',
#   'novel:category': '时空穿梭',
#   'novel:author': '火中物',
#   'novel:book_name': '我真没想当救世主啊',
#   'novel:read_url': 'https://book.qidian.com/info/1016970531/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/5362063/',
#   'novel:update_time': '2021-05-29',
#   'novel:latest_chapter_name': '新书复活帝国即将上架，恳请支持',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1016970531/654001097/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1015493157/',
#   'type': 'novel',
#   'title': '别叫我歌神',
#   'description': '\u3000\u3000谷小白不想当歌神，他只想当大物理学家。\n但系统不同意。\n没关系，还可以两开花。\n（学霸+音乐，偏专业向，非抄歌流，一切情节围绕音乐展开，基本不涉足其他娱乐或商业领域。）\n群：8520910',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1015493157/180',
#   'novel:category': '娱乐明星',
#   'novel:author': '君不见',
#   'novel:book_name': '别叫我歌神',
#   'novel:read_url': 'https://book.qidian.com/info/1015493157/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/4406488/',
#   'novel:update_time': '9小时前',
#   'novel:latest_chapter_name': '第1899章：臣欲死战，陛下为何先降',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1015493157/701253129/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1021708634/',
#   'type': 'novel',
#   'title': '柯学验尸官',
#   'description': '\u3000\u3000【这是柯南同人】本书全称：《刚穿越到柯学世界就被名侦探指认为头号犯罪嫌疑人，身为验尸官的我现在一点不慌》',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1021708634/180',
#   'novel:category': '衍生同人',
#   'novel:author': '河流之汪',
#   'novel:book_name': '柯学验尸官',
#   'novel:read_url': 'https://book.qidian.com/info/1021708634/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/400932125/',
#   'novel:update_time': '2021-10-18',
#   'novel:latest_chapter_name': '完本感言',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1021708634/679052062/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1010510263/',
#   'type': 'novel',
#   'title': '暗影熊提伯斯的位面之旅',
#   'description': '\u3000\u3000ʕ๑•ɷ•๑ʔ❀这是一本挂着小熊提伯斯的熊头，卖着小安妮的噱头的书!\n噢，手误，写错了……\nฅ۶•ﻌ•❤这其实是一本挂着提伯斯的熊头，卖着小安妮的多元世界旅行故事的书！\n没错了，就是酱紫的！\n⁽⁽ଘ( Ծ‿- )ଓ⁾⁾无尽的世界，无尽的幻想的，轻松惬意的位面之旅，快来看看吖……\n目前已过漫威、霍格沃茨、艾泽拉斯世界、加勒比海盗、星际争霸、指环王、神盾局、暗黑破坏神、FATE、质量效应、白蛇传、权力的游戏、七龙珠、DC女超人、符文之地、黑衣人、高达SEED、封神世界、学园都市、星球大战、红楼梦、功夫熊猫、光环：致远星、上古卷轴、头号玩家、骨傲天、矿石镇的伙伴、雄兵连，魔女之旅、妖精的尾巴、仙剑、刀剑、琦玉、大航海、从零开始、美食俘虏、海贼王，目前正在【梦幻模拟战】\n【一天一更，一更万字！】',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1010510263/180',
#   'novel:category': '诸天',
#   'novel:author': '暗影熊',
#   'novel:book_name': '暗影熊提伯斯的位面之旅',
#   'novel:read_url': 'https://book.qidian.com/info/1010510263/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/12790520/',
#   'novel:update_time': '9小时前',
#   'novel:latest_chapter_name': '第1794章(*๓´ꌂ`๓)你们已经死了',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1010510263/701102075/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1017204010/',
#   'type': 'novel',
#   'title': '真千金她是全能大佬',
#   'description': '\u3000\u3000【新文《被夺一切后她封神回归》已开，已签约出版】\n 【1v1双洁、团宠、塔罗牌、神医、甜燃爽！】\n 昔日大佬嬴子衿一觉醒来，成了嬴家丢了十五年的小女儿，而嬴家果断收养了一个孩子替代她。\n 回到豪门后，人人嘲讽她不如假千金聪明能干，懂事优雅。\n 父母更视她为家族污点，警告她不要妄想大小姐的位置，有一个养女的名头就该识趣，不然就把她送回去。\n 嬴子衿：这就走，不用送。\n 在嬴家欢天喜地庆祝，其他人都在坐看真千金笑话的时候，各个领域的大佬们纷纷出动了。 粉丝战斗力top的顶流影帝：嬴小姐有什么需要的，尽管吩咐。\n 垄断全球经济的财阀继承人：嬴家？什么东西？老大，直接灭了吧？\n 华国第一古武者：谁敢欺负师傅？\n 智商高达228的天才少年：我姐姐。\n 拥有极致妖孽容颜的男人勾唇一笑，散漫慵懒：“那好，叫姐夫吧。”\n 大佬们：？？？\n 真千金原大佬身份一夕恢复，全网炸了，嬴家疯了，哭着跪着求她回来。\n国际巨佬家族：不好意思，介绍一下，这是我们本家大小姐。\n ·\n 王者重生，强势翻盘，绝地反击！\n #神算女王两百年后再回地球，曾经的小弟们都成了大佬#',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1017204010/180',
#   'novel:category': '豪门世家',
#   'novel:author': '卿浅',
#   'novel:book_name': '真千金她是全能大佬',
#   'novel:read_url': 'https://book.qidian.com/info/1017204010/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/403324877/',
#   'novel:update_time': '2021-12-30',
#   'novel:latest_chapter_name': '联动番外：嬴皇傅小团子后记【新书求收】',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1017204010/689591615/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1004173553/',
#   'type': 'novel',
#   'title': '女帝直播攻略',
#   'description': '\u3000\u3000【新书《退下，让朕来》正在火热连载。】<br>\u3000\u3000【不一样的故事，同样的精彩】<br>\u3000\u3000姜芃姬获得一个号称宫斗直播系统的东西。<br>\u3000\u3000姜芃姬：“好的系统，没问题系统！”<br>\u3000\u3000多年之后，姜芃姬终于达成目标，她成为皇帝的女人（女帝）。<br>\u3000\u3000姜芃姬：“求夸奖！”<br>\u3000\u3000系统：“(╯‵□′)╯︵┻━┻让你去宫斗，谁让你去打天下了！”<br>\u3000\u3000#未来上将在古代的诸侯争霸之路#<br>\u3000\u3000#男主看了沉默，系统看了流泪#',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1004173553/180',
#   'novel:category': '东方玄幻',
#   'novel:author': '油爆香菇',
#   'novel:book_name': '女帝直播攻略',
#   'novel:read_url': 'https://book.qidian.com/info/1004173553/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/3202780/',
#   'novel:update_time': '2019-02-02',
#   'novel:latest_chapter_name': '新书《大佬退休之后》',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1004173553/449370991/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1011448624/',
#   'type': 'novel',
#   'title': '次元法典',
#   'description': '\u3000\u3000当方正睁开眼睛时，惊讶的发现自己重生到了一个龙与魔法，骑士与公主的幻想世界。不仅如此，甚至连方正之前所设计的游戏系统，也一并跟随他来到了这个世界。那么接下来，就是穿越万千位面，获得无穷力量，成为勇者，击败魔王迎娶公主，走上人生巅峰了………等等，在那之前，为什么我重生的是一个人人喊打的？',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1011448624/180',
#   'novel:category': '游戏异界',
#   'novel:author': '西贝猫',
#   'novel:book_name': '次元法典',
#   'novel:read_url': 'https://book.qidian.com/info/1011448624/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/4362251/',
#   'novel:update_time': '10小时前',
#   'novel:latest_chapter_name': '第三千二百九十五章 魔王来访（黑魂类真不适合做开放世界）',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1011448624/701247194/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1029006481/',
#   'type': 'novel',
#   'title': '不科学御兽',
#   'description': '\u3000\u3000这是一个以御兽为主流的异世界。\n动物，植物，元素，死灵，机械……九尾炎狐，生命古树，雷云精灵，骷髅君主，机械舰娘乃至孕育出灵的古董刀剑皆可作为宠兽，而契约、培养，御使它们的人类，则被统称为御兽师！\n神话学者兼考古学家时宇穿越而来，为了探寻空白的历史与失落的神话，他选择踏上了一条极为不科学的御兽之路…',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1029006481/180',
#   'novel:category': '异世大陆',
#   'novel:author': '轻泉流响',
#   'novel:book_name': '不科学御兽',
#   'novel:read_url': 'https://m.qidian.com/book/1029006481',
#   'novel:status': '连载',
#   'novel:author_link': 'https://m.qidian.com/author/400116550/',
#   'novel:update_time': '11小时前',
#   'novel:latest_chapter_name': '第358章：冻结时间的天霜寒气',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1029006481/701019327',
#   'altsite': 'https://www.biqugee.com/book/49472/'},
#  {'url': 'https://book.qidian.com/info/1015493157/',
#   'type': 'novel',
#   'title': '别叫我歌神',
#   'description': '\u3000\u3000谷小白不想当歌神，他只想当大物理学家。\n但系统不同意。\n没关系，还可以两开花。\n（学霸+音乐，偏专业向，非抄歌流，一切情节围绕音乐展开，基本不涉足其他娱乐或商业领域。）\n群：8520910',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1015493157/180',
#   'novel:category': '娱乐明星',
#   'novel:author': '君不见',
#   'novel:book_name': '别叫我歌神',
#   'novel:read_url': 'https://m.qidian.com/book/1015493157',
#   'novel:status': '连载',
#   'novel:author_link': 'https://m.qidian.com/author/4406488/',
#   'novel:update_time': '9小时前',
#   'novel:latest_chapter_name': '第1899章：臣欲死战，陛下为何先降',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1015493157/701253129',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1027606717/',
#   'type': 'novel',
#   'title': '我绑架了时间线',
#   'description': '\u3000\u3000每一次改写现实，都会让未来发生变化。\n见证了1500年后人类文明的灭亡，意外获得穿越未来能力的封棋选择了不断重启时间线，通过情报为人类文明博取一线生机。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1027606717/180',
#   'novel:category': '时空穿梭',
#   'novel:author': '一刀斩斩斩',
#   'novel:book_name': '我绑架了时间线',
#   'novel:read_url': 'https://book.qidian.com/info/1027606717/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/403500782/',
#   'novel:update_time': '昨日18:12',
#   'novel:latest_chapter_name': '第338章 奇迹再现（感谢小疯子哥哥哥哥哥打赏的盟主）',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1027606717/701213214/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1013414929/',
#   'type': 'novel',
#   'title': '手术直播间',
#   'description': '\u3000\u3000一个外科的小医生，一不小心得到了系统加持，横扫医学界，妙手回春，活人无数。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1013414929/180',
#   'novel:category': '都市生活',
#   'novel:author': '真熊初墨',
#   'novel:book_name': '手术直播间',
#   'novel:read_url': 'https://book.qidian.com/info/1013414929/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/403278015/',
#   'novel:update_time': '2021-07-15',
#   'novel:latest_chapter_name': '新书《回到2002当医生》已上传',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1013414929/661580550/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1021617576/',
#   'type': 'novel',
#   'title': '夜的命名术',
#   'description': '\u3000\u3000蓝与紫的霓虹中，浓密的钢铁苍穹下，数据洪流的前端，是科技革命之后的世界，也是现实与虚幻的分界。<br>\u3000\u3000钢铁与身体，过去与未来。<br>\u3000\u3000这里，表世界与里世界并存，面前的一切，像是时间之墙近在眼前。<br>\u3000\u3000黑暗逐渐笼罩。<br>\u3000\u3000可你要明白啊我的朋友，我们不能用温柔去应对黑暗，要用火。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1021617576/180',
#   'novel:category': '异术超能',
#   'novel:author': '会说话的肘子',
#   'novel:book_name': '夜的命名术',
#   'novel:read_url': 'https://book.qidian.com/info/1021617576/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/5175790/',
#   'novel:update_time': '5小时前',
#   'novel:latest_chapter_name': '683、杀死懦弱的自己，成为英雄吧！',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1021617576/704460353/',
#   'altsite': 'https://www.ddyueshu.com/27171_27171574/'},
#  {'url': 'https://book.qidian.com/info/1029006481/',
#   'type': 'novel',
#   'title': '不科学御兽',
#   'description': '\u3000\u3000这是一个以御兽为主流的异世界。\n动物，植物，元素，死灵，机械……九尾炎狐，生命古树，雷云精灵，骷髅君主，机械舰娘乃至孕育出灵的古董刀剑皆可作为宠兽，而契约、培养，御使它们的人类，则被统称为御兽师！\n神话学者兼考古学家时宇穿越而来，为了探寻空白的历史与失落的神话，他选择踏上了一条极为不科学的御兽之路…',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1029006481/180',
#   'novel:category': '异世大陆',
#   'novel:author': '轻泉流响',
#   'novel:book_name': '不科学御兽',
#   'novel:read_url': 'https://book.qidian.com/info/1029006481/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/400116550/',
#   'novel:update_time': '24小时前',
#   'novel:latest_chapter_name': '第377章：狩猎霸主',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1029006481/704361591/',
#   'altsite': 'https://www.biqugee.com/book/49472/'},
#  {'url': 'https://book.qidian.com/info/1025901449/',
#   'type': 'novel',
#   'title': '我的治愈系游戏',
#   'description': '\u3000\u3000警察同志，如果我说这是一款休闲治愈系游戏，你们信吗？',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1025901449/180',
#   'novel:category': '侦探推理',
#   'novel:author': '我会修空调',
#   'novel:book_name': '我的治愈系游戏',
#   'novel:read_url': 'https://book.qidian.com/info/1025901449/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/402573440/',
#   'novel:update_time': '昨日20:13',
#   'novel:latest_chapter_name': '第659章 这不是我想吃的肉',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1025901449/704377183/',
#   'altsite': 'https://www.biqugee.com/book/42560/'},
#  {'url': 'https://book.qidian.com/info/1013293257/',
#   'type': 'novel',
#   'title': '舌尖上的霍格沃茨',
#   'description': '\u3000\u3000艾琳娜·卡斯兰娜，混血媚娃，危险等级：【极度致命】<br>\u3000\u3000她消弭了千年来学院间的纷争，让霍格沃茨成为圣地。<br>\u3000\u3000她挽救了无数濒危的神奇动物，增进人与自然的了解。<br>\u3000\u3000她促使了魔法与非魔法的融合，找到两者共存平衡点。<br>\u3000\u3000她有着无数耀眼的头衔——霍格沃茨大姐头、古灵阁之主、三代目黑魔王、顶端掠食者、苏格兰圆脸胖鸡之敌、首席特级厨师……<br>\u3000\u3000在她的成长经历中，有无数璀璨的姓名，邓布利多、格林德沃、斯卡曼德……<br>\u3000\u3000——下面我们来采访一下邓布利多。<br>\u3000\u3000“您好，能分享一些卡斯兰娜女士在学校的故事吗？”<br>\u3000\u3000阿不思·心好累好想退休·邓布利多：快……快，我需要速效救心丸！<br>\u3000\u3000【慎入，女主文】',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1013293257/180',
#   'novel:category': '现代魔法',
#   'novel:author': '幽萌之羽',
#   'novel:book_name': '舌尖上的霍格沃茨',
#   'novel:read_url': 'https://book.qidian.com/info/1013293257/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/400090919/',
#   'novel:update_time': '2022-03-18',
#   'novel:latest_chapter_name': '第1251章 影响因子',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1013293257/704231724/',
#   'altsite': 'https://www.biqugee.com/book/25454/'},
#  {'url': 'https://book.qidian.com/info/2718601/',
#   'type': 'novel',
#   'title': '进化的四十六亿重奏',
#   'description': '\u3000\u3000从一颗星球的生命诞生之初起跑，将会见证无数文明的兴亡衰落，物种的诞生与灭亡，在数不尽的天灾地变之下，没有什么是永恒不变的，只有不停的改变自身，在逆境之中不停进化，才能成就完美的胜利。<br>\u3000\u3000故事，将从一个小小的细胞开始……<br>\u3000\u3000《重奏》普一群：494981693(千人群)\n\n《重奏》普二群：702899130\n\n重奏VIP群:695413196，入群粉丝值10000',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/2718601/180',
#   'novel:category': '进化变异',
#   'novel:author': '相位行者',
#   'novel:book_name': '进化的四十六亿重奏',
#   'novel:read_url': 'https://book.qidian.com/info/2718601/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/2265405/',
#   'novel:update_time': '2022-03-17',
#   'novel:latest_chapter_name': '第四十五章 入侵',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/2718601/703857266/',
#   'altsite': 'https://www.biqugee.com/book/1876/'},
#  {'url': 'https://book.qidian.com/info/1025263752/',
#   'type': 'novel',
#   'title': '二进制亡者列车',
#   'description': '\u3000\u3000图灵误入了一辆满载科技世界亡者的列车。<br>\u3000\u3000进入亡者原本的世界，完成已死之人的遗愿，就能得到他们的高科技知识：<br>\u3000\u3000把血肉变成机械的脱碳原液。<br>\u3000\u3000人造血循环科技吸血鬼。<br>\u3000\u3000入侵大脑的神经拷问技术。<br>\u3000\u3000随时想着夺舍的智能人格。<br>\u3000\u3000空间坍缩炸弹和储物立方。<br>\u3000\u3000高周波武士刀…………<br>\u3000\u3000接着，图灵发现，他还能升级这些知识造物。<br>\u3000\u3000于是，植入式战术目镜变成了高科技眼球：战场透视，自动索敌。<br>\u3000\u3000全息投影器变成了骗术师外骨骼：虚拟分身，容貌覆盖。<br>\u3000\u3000激光炮变成了透射歼星炮。武士刀变成了高频斩舰刀。<br>\u3000\u3000防护罩变成了AT立场……<br>\u3000\u3000机械朋克，意识夺舍。<br>\u3000\u3000血肉苦弱，机械飞升！<br>\u3000\u3000书友群:306055573',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1025263752/180',
#   'novel:category': '无限',
#   'novel:author': 'Krache',
#   'novel:book_name': '二进制亡者列车',
#   'novel:read_url': 'https://book.qidian.com/info/1025263752/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/400480300/',
#   'novel:update_time': '2022-03-13',
#   'novel:latest_chapter_name': '第五百七十七章 再提升',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1025263752/703282111/',
#   'altsite': 'https://www.biqugee.com/book/41199/'},
#  {'url': 'https://book.qidian.com/info/1022282526/',
#   'type': 'novel',
#   'title': '全职艺术家',
#   'description': '\u3000\u3000“音乐、影视、绘画、书法、雕塑、文学……”\n“你都懂？”\n“略知一二。”\n“都会一点的意思？”\n“嗯，都会亿点的意思。”\n怀揣系统，靠艺术征服世界，成为各界人士顶礼膜拜的无冕之王。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1022282526/180',
#   'novel:category': '娱乐明星',
#   'novel:author': '我最白',
#   'novel:book_name': '全职艺术家',
#   'novel:read_url': 'https://book.qidian.com/info/1022282526/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/4953220/',
#   'novel:update_time': '昨日00:16',
#   'novel:latest_chapter_name': '第一千二百七十八章 火爆全球的《羡鱼文集》',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1022282526/704235381/',
#   'altsite': 'https://www.biqugee.com/book/37421/'},
#  {'url': 'https://book.qidian.com/info/1015493157/',
#   'type': 'novel',
#   'title': '别叫我歌神',
#   'description': '\u3000\u3000谷小白不想当歌神，他只想当大物理学家。\n但系统不同意。\n没关系，还可以两开花。\n（学霸+音乐，偏专业向，非抄歌流，一切情节围绕音乐展开，基本不涉足其他娱乐或商业领域。）\n群：8520910',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1015493157/180',
#   'novel:category': '娱乐明星',
#   'novel:author': '君不见',
#   'novel:book_name': '别叫我歌神',
#   'novel:read_url': 'https://book.qidian.com/info/1015493157/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/4406488/',
#   'novel:update_time': '22小时前',
#   'novel:latest_chapter_name': '第1918章：“冰上乐园”和王贯山的“大船长系统”',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1015493157/704404588/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1021708634/',
#   'type': 'novel',
#   'title': '柯学验尸官',
#   'description': '\u3000\u3000【这是柯南同人】本书全称：《刚穿越到柯学世界就被名侦探指认为头号犯罪嫌疑人，身为验尸官的我现在一点不慌》',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1021708634/180',
#   'novel:category': '衍生同人',
#   'novel:author': '河流之汪',
#   'novel:book_name': '柯学验尸官',
#   'novel:read_url': 'https://book.qidian.com/info/1021708634/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/400932125/',
#   'novel:update_time': '2022-03-06',
#   'novel:latest_chapter_name': '新书《法医的时间旅行日志》',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1021708634/702234420/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1010510263/',
#   'type': 'novel',
#   'title': '暗影熊提伯斯的位面之旅',
#   'description': '\u3000\u3000ʕ๑•ɷ•๑ʔ❀这是一本挂着小熊提伯斯的熊头，卖着小安妮的噱头的书!\n噢，手误，写错了……\nฅ۶•ﻌ•❤这其实是一本挂着提伯斯的熊头，卖着小安妮的多元世界旅行故事的书！\n没错了，就是酱紫的！\n⁽⁽ଘ( Ծ‿- )ଓ⁾⁾无尽的世界，无尽的幻想的，轻松惬意的位面之旅，快来看看吖……\n目前已过漫威、霍格沃茨、艾泽拉斯世界、加勒比海盗、星际争霸、指环王、神盾局、暗黑破坏神、FATE、质量效应、白蛇传、权力的游戏、七龙珠、DC女超人、符文之地、黑衣人、高达SEED、封神世界、学园都市、星球大战、红楼梦、功夫熊猫、光环：致远星、上古卷轴、头号玩家、骨傲天、矿石镇的伙伴、雄兵连，魔女之旅、妖精的尾巴、仙剑、刀剑、琦玉、大航海、从零开始、美食俘虏、海贼王，目前正在【梦幻模拟战】\n【一天一更，一更万字！】',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1010510263/180',
#   'novel:category': '诸天',
#   'novel:author': '暗影熊',
#   'novel:book_name': '暗影熊提伯斯的位面之旅',
#   'novel:read_url': 'https://book.qidian.com/info/1010510263/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/12790520/',
#   'novel:update_time': '9小时前',
#   'novel:latest_chapter_name': "第1832章=͟͟͞͞( 'ヮ' =͟͟͞͞)黑子想要的脑袋",
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1010510263/704442640/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1011448624/',
#   'type': 'novel',
#   'title': '次元法典',
#   'description': '\u3000\u3000当方正睁开眼睛时，惊讶的发现自己重生到了一个龙与魔法，骑士与公主的幻想世界。不仅如此，甚至连方正之前所设计的游戏系统，也一并跟随他来到了这个世界。那么接下来，就是穿越万千位面，获得无穷力量，成为勇者，击败魔王迎娶公主，走上人生巅峰了………等等，在那之前，为什么我重生的是一个人人喊打的？',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1011448624/180',
#   'novel:category': '游戏异界',
#   'novel:author': '西贝猫',
#   'novel:book_name': '次元法典',
#   'novel:read_url': 'https://book.qidian.com/info/1011448624/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/4362251/',
#   'novel:update_time': '8小时前',
#   'novel:latest_chapter_name': '第三千三百三十六章 一百亿（等着玩幽灵线东京）',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1011448624/704446687/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1027606717/',
#   'type': 'novel',
#   'title': '我绑架了时间线',
#   'description': '\u3000\u3000每一次改写现实，都会让未来发生变化。\n见证了1500年后人类文明的灭亡，意外获得穿越未来能力的封棋选择了不断重启时间线，通过情报为人类文明博取一线生机。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1027606717/180',
#   'novel:category': '时空穿梭',
#   'novel:author': '一刀斩斩斩',
#   'novel:book_name': '我绑架了时间线',
#   'novel:read_url': 'https://book.qidian.com/info/1027606717/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/403500782/',
#   'novel:update_time': '16小时前',
#   'novel:latest_chapter_name': '第357章 我大哥贼厉害（10800字大章）',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1027606717/704418721/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1010144088/',
#   'type': 'novel',
#   'title': '无限先知',
#   'description': '\u3000\u3000新书已发《邪神竟是我自己！》记得要打感叹号。\n徐越穿越到了一个与地球有些类似的平行世界，而后被拉入了这个世界的轮回空间，有趣的是，只有他才知道轮回空间诸多世界当中的剧情。\n“你知道吗？忍村大战的最终BOSS叫大蛇丸……”\n火影、巨人、死神、食戟、漫威、高达、艾泽拉斯、一拳、柯南、overlord、fate、龙珠、哈利波特、仙剑、棋魂、DC、盘龙、杀戮都市、遮天、港综圣杯、一世之尊、诡秘之主……\n靠着对剧情先知先觉的理解，一步先步步先！\nPS1：已完本《星际传承》《唯一进化者》《机甲战神》《破法之眼》节操满满放心食用。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1010144088/180',
#   'novel:category': '无限',
#   'novel:author': '吴杰超',
#   'novel:book_name': '无限先知',
#   'novel:read_url': 'https://book.qidian.com/info/1010144088/',
#   'novel:status': '完本',
#   'novel:author_link': 'https://my.qidian.com/author/4362734/',
#   'novel:update_time': '2022-03-04',
#   'novel:latest_chapter_name': '完本感言',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1010144088/702053525/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1021617576/',
#   'type': 'novel',
#   'title': '夜的命名术',
#   'description': '\u3000\u3000蓝与紫的霓虹中，浓密的钢铁苍穹下，数据洪流的前端，是科技革命之后的世界，也是现实与虚幻的分界。<br>\u3000\u3000钢铁与身体，过去与未来。<br>\u3000\u3000这里，表世界与里世界并存，面前的一切，像是时间之墙近在眼前。<br>\u3000\u3000黑暗逐渐笼罩。<br>\u3000\u3000可你要明白啊我的朋友，我们不能用温柔去应对黑暗，要用火。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1021617576/180',
#   'novel:category': '异术超能',
#   'novel:author': '会说话的肘子',
#   'novel:book_name': '夜的命名术',
#   'novel:read_url': 'https://book.qidian.com/info/1021617576/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/5175790/',
#   'novel:update_time': '6小时前',
#   'novel:latest_chapter_name': '683、杀死懦弱的自己，成为英雄吧！',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1021617576/704460353/',
#   'altsite': 'https://www.ddyueshu.com/27171_27171574/'},
#  {'url': 'https://book.qidian.com/info/1029006481/',
#   'type': 'novel',
#   'title': '不科学御兽',
#   'description': '\u3000\u3000这是一个以御兽为主流的异世界。\n动物，植物，元素，死灵，机械……九尾炎狐，生命古树，雷云精灵，骷髅君主，机械舰娘乃至孕育出灵的古董刀剑皆可作为宠兽，而契约、培养，御使它们的人类，则被统称为御兽师！\n神话学者兼考古学家时宇穿越而来，为了探寻空白的历史与失落的神话，他选择踏上了一条极为不科学的御兽之路…',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1029006481/180',
#   'novel:category': '异世大陆',
#   'novel:author': '轻泉流响',
#   'novel:book_name': '不科学御兽',
#   'novel:read_url': 'https://book.qidian.com/info/1029006481/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/400116550/',
#   'novel:update_time': '46分钟前',
#   'novel:latest_chapter_name': '第378章：不死太阳参',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1029006481/704448928/',
#   'altsite': 'https://www.biqugee.com/book/49472/'},
#  {'url': 'https://book.qidian.com/info/1025901449/',
#   'type': 'novel',
#   'title': '我的治愈系游戏',
#   'description': '\u3000\u3000警察同志，如果我说这是一款休闲治愈系游戏，你们信吗？',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1025901449/180',
#   'novel:category': '侦探推理',
#   'novel:author': '我会修空调',
#   'novel:book_name': '我的治愈系游戏',
#   'novel:read_url': 'https://book.qidian.com/info/1025901449/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/402573440/',
#   'novel:update_time': '51分钟前',
#   'novel:latest_chapter_name': '第660章 偶尔放松一下',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1025901449/704488424/',
#   'altsite': 'https://www.biqugee.com/book/42560/'},
#  {'url': 'https://book.qidian.com/info/1016150754/',
#   'type': 'novel',
#   'title': '亏成首富从游戏开始',
#   'description': '\u3000\u3000近日，特约记者对腾达集团总裁裴谦做了专访。\n腾达集团目前估值已达千亿级别，业务涉及游戏、互联网、数码硬件、文化传媒、餐饮等多个领域，深刻地改变了人们生活的方方面面。\n而裴谦，也被视为“绝世好老板”、“不世出的投资奇才”、“天才游戏制作人”，拥有“无为而治的管理才能”和“对行业风向的精确洞察力”。\n面对记者，裴谦大吐苦水。\n“我真不是什么商业奇才啊！”\n“我的成功，完完全全都是运气使然！”\n“我最初的目标，只是想亏光五万块而已……”\n看，商业天才的人生就是这么的谦虚而又低调。\n书友群：\n792351511（新群）\n1064135703（快满了）\n893157567（快满了）',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1016150754/180',
#   'novel:category': '游戏系统',
#   'novel:author': '青衫取醉',
#   'novel:book_name': '亏成首富从游戏开始',
#   'novel:read_url': 'https://m.qidian.com/book/1016150754',
#   'novel:status': '完本',
#   'novel:author_link': 'https://m.qidian.com/author/10454296/',
#   'novel:update_time': '21分钟前',
#   'novel:latest_chapter_name': '新书《我的玩家都是演技派》',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1016150754/704491243',
#   'altsite': 'https://www.biqugee.com/book/30784/'},
#  {'url': 'https://book.qidian.com/info/3681932/',
#   'type': 'novel',
#   'title': '名侦探世界里的巫师',
#   'description': '\u3000\u3000一个末法时代的鬼巫师车祸被撞死，灵魂穿越，发现自己来了日本，附体在了一个日本人的身上。<br>\u3000\u3000正想着要在日本闯出一个名堂来，结果顺手拿起一份报纸扫了一眼——<br>\u3000\u3000工藤新一，日本平成年代的福尔摩斯，警察的救世主？<br>\u3000\u3000卧槽，老子怎么穿到二次元的世界里了？<br>\u3000\u3000嗯，总而言之，这是一个巫师在柯南世界里充当路人甲的故事……<br>\u3000\u3000PS：作者菌另外有完本作品《炼鬼修仙》653万字，《邪道鬼尊》365万字，《我的机械章鱼》218万字。闲着无聊的朋友们，可以去看下。<br>\u3000\u3000好吧，还有一本《最后的修仙者》，此书被封中，所以无视掉吧……<br>\u3000\u3000群号：512240405，已满~二群：670934518',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/3681932/180',
#   'novel:category': '衍生同人',
#   'novel:author': '追梦人Love平',
#   'novel:book_name': '名侦探世界里的巫师',
#   'novel:read_url': 'https://m.qidian.com/book/3681932',
#   'novel:status': '连载',
#   'novel:author_link': 'https://m.qidian.com/author/1630719/',
#   'novel:update_time': '2021-01-24',
#   'novel:latest_chapter_name': '第2260章 今天太阳是打西边出来了吗？',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/3681932/632126698',
#   'altsite': 'https://www.biqugee.com/book/15409/'},
#  {'url': 'https://book.qidian.com/info/1015493157/',
#   'type': 'novel',
#   'title': '别叫我歌神',
#   'description': '\u3000\u3000谷小白不想当歌神，他只想当大物理学家。\n但系统不同意。\n没关系，还可以两开花。\n（学霸+音乐，偏专业向，非抄歌流，一切情节围绕音乐展开，基本不涉足其他娱乐或商业领域。）\n群：8520910',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1015493157/180',
#   'novel:category': '娱乐明星',
#   'novel:author': '君不见',
#   'novel:book_name': '别叫我歌神',
#   'novel:read_url': 'https://book.qidian.com/info/1015493157/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/4406488/',
#   'novel:update_time': '23小时前',
#   'novel:latest_chapter_name': '第1918章：“冰上乐园”和王贯山的“大船长系统”',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1015493157/704404588/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1010510263/',
#   'type': 'novel',
#   'title': '暗影熊提伯斯的位面之旅',
#   'description': '\u3000\u3000ʕ๑•ɷ•๑ʔ❀这是一本挂着小熊提伯斯的熊头，卖着小安妮的噱头的书!\n噢，手误，写错了……\nฅ۶•ﻌ•❤这其实是一本挂着提伯斯的熊头，卖着小安妮的多元世界旅行故事的书！\n没错了，就是酱紫的！\n⁽⁽ଘ( Ծ‿- )ଓ⁾⁾无尽的世界，无尽的幻想的，轻松惬意的位面之旅，快来看看吖……\n目前已过漫威、霍格沃茨、艾泽拉斯世界、加勒比海盗、星际争霸、指环王、神盾局、暗黑破坏神、FATE、质量效应、白蛇传、权力的游戏、七龙珠、DC女超人、符文之地、黑衣人、高达SEED、封神世界、学园都市、星球大战、红楼梦、功夫熊猫、光环：致远星、上古卷轴、头号玩家、骨傲天、矿石镇的伙伴、雄兵连，魔女之旅、妖精的尾巴、仙剑、刀剑、琦玉、大航海、从零开始、美食俘虏、海贼王，目前正在【梦幻模拟战】\n【一天一更，一更万字！】',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1010510263/180',
#   'novel:category': '诸天',
#   'novel:author': '暗影熊',
#   'novel:book_name': '暗影熊提伯斯的位面之旅',
#   'novel:read_url': 'https://book.qidian.com/info/1010510263/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/12790520/',
#   'novel:update_time': '10小时前',
#   'novel:latest_chapter_name': "第1832章=͟͟͞͞( 'ヮ' =͟͟͞͞)黑子想要的脑袋",
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1010510263/704442640/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1011448624/',
#   'type': 'novel',
#   'title': '次元法典',
#   'description': '\u3000\u3000当方正睁开眼睛时，惊讶的发现自己重生到了一个龙与魔法，骑士与公主的幻想世界。不仅如此，甚至连方正之前所设计的游戏系统，也一并跟随他来到了这个世界。那么接下来，就是穿越万千位面，获得无穷力量，成为勇者，击败魔王迎娶公主，走上人生巅峰了………等等，在那之前，为什么我重生的是一个人人喊打的？',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1011448624/180',
#   'novel:category': '游戏异界',
#   'novel:author': '西贝猫',
#   'novel:book_name': '次元法典',
#   'novel:read_url': 'https://book.qidian.com/info/1011448624/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/4362251/',
#   'novel:update_time': '9小时前',
#   'novel:latest_chapter_name': '第三千三百三十六章 一百亿（等着玩幽灵线东京）',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1011448624/704446687/',
#   'altsite': 'autoSearchFailed'},
#  {'url': 'https://book.qidian.com/info/1027606717/',
#   'type': 'novel',
#   'title': '我绑架了时间线',
#   'description': '\u3000\u3000每一次改写现实，都会让未来发生变化。\n见证了1500年后人类文明的灭亡，意外获得穿越未来能力的封棋选择了不断重启时间线，通过情报为人类文明博取一线生机。',
#   'image': '//bookcover.yuewen.com/qdbimg/349573/1027606717/180',
#   'novel:category': '时空穿梭',
#   'novel:author': '一刀斩斩斩',
#   'novel:book_name': '我绑架了时间线',
#   'novel:read_url': 'https://book.qidian.com/info/1027606717/',
#   'novel:status': '连载',
#   'novel:author_link': 'https://my.qidian.com/author/403500782/',
#   'novel:update_time': '17小时前',
#   'novel:latest_chapter_name': '第357章 我大哥贼厉害（10800字大章）',
#   'novel:latest_chapter_url': '//vipreader.qidian.com/chapter/1027606717/704418721/',
#   'altsite': 'autoSearchFailed'}]
